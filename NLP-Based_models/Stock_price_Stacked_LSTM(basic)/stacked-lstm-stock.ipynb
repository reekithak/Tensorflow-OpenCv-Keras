# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/stockmarketprediction/AAPL.csv

# %%
import pandas as pd
import pandas_datareader as pdr

# %%
df = pd.read_csv("/kaggle/input/stockmarketprediction/AAPL.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 symbol                       date    close     high     low  \
# 0           0   AAPL  2015-05-27 00:00:00+00:00  132.045  132.260  130.05
# 1           1   AAPL  2015-05-28 00:00:00+00:00  131.780  131.950  131.10
# 2           2   AAPL  2015-05-29 00:00:00+00:00  130.280  131.450  129.90
# 3           3   AAPL  2015-06-01 00:00:00+00:00  130.535  131.390  130.05
# 4           4   AAPL  2015-06-02 00:00:00+00:00  129.960  130.655  129.32
#
#      open    volume    adjClose     adjHigh      adjLow     adjOpen  \
# 0  130.34  45833246  121.682558  121.880685  119.844118  120.111360
# 1  131.86  30733309  121.438354  121.595013  120.811718  121.512076
# 2  131.23  50884452  120.056069  121.134251  119.705890  120.931516
# 3  131.20  32112797  120.291057  121.078960  119.844118  120.903870
# 4  129.86  33667627  119.761181  120.401640  119.171406  119.669029
#
#    adjVolume  divCash  splitFactor
# 0   45833246      0.0          1.0
# 1   30733309      0.0          1.0
# 2   50884452      0.0          1.0
# 3   32112797      0.0          1.0
# 4   33667627      0.0          1.0

# %%
df1 = df.reset_index()['close']
df1.shape
# Out:
# (1258,)

# %%
import matplotlib.pyplot as plt
plt.plot(df1)

# %%
#Transforming values between 0 - 1 for scalability 
import numpy as np 
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))

df1 = scaler.fit_transform(np.array(df1).reshape(-1,1))  #-1,1 for transform function
df1.shape
# Out:
# (1258, 1)

# %%
df1
# Out:
# array([[0.17607447],
#        [0.17495567],
#        [0.16862282],
#        ...,
#        [0.96635143],
#        [0.9563033 ],
#        [0.96491598]])

# %%
#Time series split ? ---> Training = 70% Test = 30% (there is data dependency)

training_size = int(len(df1)*0.65)
test_size = len(df1)- training_size

train_data, test_data = df1[0:training_size,:] , df1[training_size:len(df1),:1]

# %%
training_size,test_size
# Out:
# (817, 441)

# %%
#Data preprocessing


def create_dataset(dataset,timestep=1):
    dataX , dataY  = [] , []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step),0]
        dataX.append(a)
        dataY.append(dataset[i+time_step,0])
        
    return np.array(dataX) , np.array(dataY)

# %%
time_step = 100  #the previuos n- data steps to consider for prediction/
x_train , y_train = create_dataset(train_data,time_step)
x_test , y_test = create_dataset(test_data,time_step)

# %%
x_train  , x_test
# Out:
# (array([[0.17607447, 0.17495567, 0.16862282, ..., 0.09055982, 0.08388922,
#          0.09085536],
#         [0.17495567, 0.16862282, 0.1696994 , ..., 0.08388922, 0.09085536,
#          0.0873934 ],
#         [0.16862282, 0.1696994 , 0.16727181, ..., 0.09085536, 0.0873934 ,
#          0.09030651],
#         ...,
#         [0.34801148, 0.32930845, 0.32145571, ..., 0.50042219, 0.50413747,
#          0.5062062 ],
#         [0.32930845, 0.32145571, 0.32694419, ..., 0.50413747, 0.5062062 ,
#          0.51920966],
#         [0.32145571, 0.32694419, 0.32230009, ..., 0.5062062 , 0.51920966,
#          0.53719497]]),
#  array([[0.52651355, 0.52837119, 0.53119986, ..., 0.26154691, 0.25187875,
#          0.26483999],
#         [0.52837119, 0.53119986, 0.53871485, ..., 0.25187875, 0.26483999,
#          0.27273495],
#         [0.53119986, 0.53871485, 0.5461454 , ..., 0.26483999, 0.27273495,
#          0.2766191 ],
#         ...,
#         [0.81875369, 0.84256523, 0.84210082, ..., 0.92544119, 0.91771511,
#          0.9483239 ],
#         [0.84256523, 0.84210082, 0.84936249, ..., 0.91771511, 0.9483239 ,
#          0.94064004],
#         [0.84210082, 0.84936249, 0.85835515, ..., 0.9483239 , 0.94064004,
#          0.96635143]]))

# %%
x_train.shape ,y_train.shape
# Out:
# ((716, 100), (716,))

# %%
#For lstm reshape into 3-D

x_train = x_train.reshape(x_train.shape[0],x_train.shape[1],1)
x_test = x_test.reshape(x_test.shape[0],x_test.shape[1],1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense , LSTM

# %%
model = Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))     #first input shape should be that of x_train
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 100, 50)           10400
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 100, 50)           20200
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 0s 22ms/step - loss: 3.6914e-04 - accuracy: 0.0014 - val_loss: 0.0036 - val_accuracy: 0.0029
# Epoch 2/100
# 12/12 [==============================] - 0s 19ms/step - loss: 5.3527e-04 - accuracy: 0.0014 - val_loss: 0.0028 - val_accuracy: 0.0029
# Epoch 3/100
# 12/12 [==============================] - 0s 20ms/step - loss: 6.0204e-04 - accuracy: 0.0014 - val_loss: 0.0016 - val_accuracy: 0.0029
# Epoch 4/100
# 12/12 [==============================] - 0s 20ms/step - loss: 4.5060e-04 - accuracy: 0.0014 - val_loss: 0.0030 - val_accuracy: 0.0029
# Epoch 5/100
# 12/12 [==============================] - 0s 18ms/step - loss: 3.7621e-04 - accuracy: 0.0014 - val_loss: 0.0017 - val_accuracy: 0.0029
# Epoch 6/100
# 12/12 [==============================] - 0s 21ms/step - loss: 3.3004e-04 - accuracy: 0.0014 - val_loss: 0.0016 - val_accuracy: 0.0029
# Epoch 7/100
# 12/12 [==============================] - 0s 21ms/step - loss: 3.4592e-04 - accuracy: 0.0014 - val_loss: 0.0021 - val_accuracy: 0.0029
# Epoch 8/100
# 12/12 [==============================] - 0s 19ms/step - loss: 3.4889e-04 - accuracy: 0.0014 - val_loss: 0.0019 - val_accuracy: 0.0029
# Epoch 9/100
# 12/12 [==============================] - 0s 18ms/step - loss: 3.2647e-04 - accuracy: 0.0014 - val_loss: 0.0015 - val_accuracy: 0.0029
# Epoch 10/100
# 12/12 [==============================] - 0s 18ms/step - loss: 3.2097e-04 - accuracy: 0.0014 - val_loss: 0.0022 - val_accuracy: 0.0029
# Epoch 11/100
# 12/12 [==============================] - 0s 19ms/step - loss: 3.2330e-04 - accuracy: 0.0014 - val_loss: 0.0015 - val_accuracy: 0.0029
# Epoch 12/100
# 12/12 [==============================] - 0s 21ms/step - loss: 3.5963e-04 - accuracy: 0.0014 - val_loss: 0.0027 - val_accuracy: 0.0029
# Epoch 13/100
# 12/12 [==============================] - 0s 18ms/step - loss: 3.8017e-04 - accuracy: 0.0014 - val_loss: 0.0015 - val_accuracy: 0.0029
# Epoch 14/100
# 12/12 [==============================] - 0s 22ms/step - loss: 4.5529e-04 - accuracy: 0.0014 - val_loss: 0.0034 - val_accuracy: 0.0029
# Epoch 15/100
# 12/12 [==============================] - 0s 32ms/step - loss: 3.9714e-04 - accuracy: 0.0014 - val_loss: 0.0015 - val_accuracy: 0.0029
# Epoch 16/100
# 12/12 [==============================] - 0s 23ms/step - loss: 3.9513e-04 - accuracy: 0.0014 - val_loss: 0.0022 - val_accuracy: 0.0029
# Epoch 17/100
# 12/12 [==============================] - 0s 18ms/step - loss: 3.4515e-04 - accuracy: 0.0014 - val_loss: 0.0017 - val_accuracy: 0.0029
# Epoch 18/100
# 12/12 [==============================] - 0s 19ms/step - loss: 3.3268e-04 - accuracy: 0.0014 - val_loss: 0.0017 - val_accuracy: 0.0029
# Epoch 19/100
# 12/12 [==============================] - 0s 24ms/step - loss: 3.3919e-04 - accuracy: 0.0014 - val_loss: 0.0023 - val_accuracy: 0.0029
# Epoch 20/100
# 12/12 [==============================] - 0s 20ms/step - loss: 3.0663e-04 - accuracy: 0.0014 - val_loss: 0.0014 - val_accuracy: 0.0029
# Epoch 21/100
# 12/12 [==============================] - 0s 19ms/step - loss: 3.4322e-04 - accuracy: 0.0014 - val_loss: 0.0025 - val_accuracy: 0.0029
# Epoch 22/100
# 12/12 [==============================] - 0s 19ms/step - loss: 2.8050e-04 - accuracy: 0.0014 - val_loss: 0.0014 - val_accuracy: 0.0029
# Epoch 23/100
# 12/12 [==============================] - 0s 18ms/step - loss: 3.1685e-04 - accuracy: 0.0014 - val_loss: 0.0024 - val_accuracy: 0.0029
# Epoch 24/100
# 12/12 [==============================] - 0s 19ms/step - loss: 3.3011e-04 - accuracy: 0.0014 - val_loss: 0.0016 - val_accuracy: 0.0029
# Epoch 25/100
# 12/12 [==============================] - 0s 18ms/step - loss: 2.7219e-04 - accuracy: 0.0014 - val_loss: 0.0024 - val_accuracy: 0.0029
# Epoch 26/100
# 12/12 [==============================] - 0s 20ms/step - loss: 2.9494e-04 - accuracy: 0.0014 - val_loss: 0.0014 - val_accuracy: 0.0029
# Epoch 27/100
# 12/12 [==============================] - 0s 19ms/step - loss: 3.0949e-04 - accuracy: 0.0014 - val_loss: 0.0017 - val_accuracy: 0.0029
# Epoch 28/100
# 12/12 [==============================] - 0s 19ms/step - loss: 2.8262e-04 - accuracy: 0.0014 - val_loss: 0.0022 - val_accuracy: 0.0029
# Epoch 29/100
# 12/12 [==============================] - 0s 19ms/step - loss: 2.8031e-04 - accuracy: 0.0014 - val_loss: 0.0014 - val_accuracy: 0.0029
# Epoch 30/100
# 12/12 [==============================] - 0s 19ms/step - loss: 3.0386e-04 - accuracy: 0.0014 - val_loss: 0.0018 - val_accuracy: 0.0029
# Epoch 31/100
# 12/12 [==============================] - 0s 19ms/step - loss: 3.3064e-04 - accuracy: 0.0014 - val_loss: 0.0014 - val_accuracy: 0.0029
# Epoch 32/100
# 12/12 [==============================] - 0s 18ms/step - loss: 3.1265e-04 - accuracy: 0.0014 - val_loss: 0.0020 - val_accuracy: 0.0029
# Epoch 33/100
# 12/12 [==============================] - 0s 19ms/step - loss: 3.3763e-04 - accuracy: 0.0014 - val_loss: 0.0015 - val_accuracy: 0.0029
# Epoch 34/100
# 12/12 [==============================] - 0s 19ms/step - loss: 2.9109e-04 - accuracy: 0.0014 - val_loss: 0.0022 - val_accuracy: 0.0029
# Epoch 35/100
# 12/12 [==============================] - 0s 19ms/step - loss: 2.5233e-04 - accuracy: 0.0014 - val_loss: 0.0014 - val_accuracy: 0.0029
# Epoch 36/100
# 12/12 [==============================] - 0s 20ms/step - loss: 2.5146e-04 - accuracy: 0.0014 - val_loss: 0.0018 - val_accuracy: 0.0029
# Epoch 37/100
# 12/12 [==============================] - 0s 19ms/step - loss: 2.6551e-04 - accuracy: 0.0014 - val_loss: 0.0019 - val_accuracy: 0.0029
# Epoch 38/100
# 12/12 [==============================] - 0s 19ms/step - loss: 2.3691e-04 - accuracy: 0.0014 - val_loss: 0.0016 - val_accuracy: 0.0029
# Epoch 39/100
# 12/12 [==============================] - 0s 18ms/step - loss: 2.4099e-04 - accuracy: 0.0014 - val_loss: 0.0021 - val_accuracy: 0.0029
# Epoch 40/100
# 12/12 [==============================] - 0s 18ms/step - loss: 2.4376e-04 - accuracy: 0.0014 - val_loss: 0.0016 - val_accuracy: 0.0029
# Epoch 41/100
# 12/12 [==============================] - 0s 19ms/step - loss: 2.3001e-04 - accuracy: 0.0014 - val_loss: 0.0019 - val_accuracy: 0.0029
# Epoch 42/100
# 12/12 [==============================] - 0s 19ms/step - loss: 2.1228e-04 - accuracy: 0.0014 - val_loss: 0.0015 - val_accuracy: 0.0029
# Epoch 43/100
# 12/12 [==============================] - 0s 18ms/step - loss: 2.1833e-04 - accuracy: 0.0014 - val_loss: 0.0014 - val_accuracy: 0.0029
# Epoch 44/100
# 12/12 [==============================] - 0s 19ms/step - loss: 2.1624e-04 - accuracy: 0.0014 - val_loss: 0.0015 - val_accuracy: 0.0029
# Epoch 45/100
# 12/12 [==============================] - 0s 19ms/step - loss: 2.1351e-04 - accuracy: 0.0014 - val_loss: 0.0016 - val_accuracy: 0.0029
# Epoch 46/100
# 12/12 [==============================] - 0s 18ms/step - loss: 2.0801e-04 - accuracy: 0.0014 - val_loss: 0.0022 - val_accuracy: 0.0029
# Epoch 47/100
# 12/12 [==============================] - 0s 18ms/step - loss: 2.4304e-04 - accuracy: 0.0014 - val_loss: 0.0014 - val_accuracy: 0.0029
# Epoch 48/100
# 12/12 [==============================] - 0s 18ms/step - loss: 2.0663e-04 - accuracy: 0.0014 - val_loss: 0.0018 - val_accuracy: 0.0029
# Epoch 49/100
# 12/12 [==============================] - 0s 18ms/step - loss: 2.0740e-04 - accuracy: 0.0014 - val_loss: 0.0013 - val_accuracy: 0.0029
# Epoch 50/100
# 12/12 [==============================] - 0s 19ms/step - loss: 2.0474e-04 - accuracy: 0.0014 - val_loss: 0.0016 - val_accuracy: 0.0029
# Epoch 51/100
# 12/12 [==============================] - 0s 19ms/step - loss: 1.9863e-04 - accuracy: 0.0014 - val_loss: 0.0020 - val_accuracy: 0.0029
# Epoch 52/100
# 12/12 [==============================] - 0s 19ms/step - loss: 2.2365e-04 - accuracy: 0.0014 - val_loss: 0.0014 - val_accuracy: 0.0029
# Epoch 53/100
# 12/12 [==============================] - 0s 19ms/step - loss: 1.9989e-04 - accuracy: 0.0014 - val_loss: 0.0014 - val_accuracy: 0.0029
# Epoch 54/100
# 12/12 [==============================] - 0s 18ms/step - loss: 1.8467e-04 - accuracy: 0.0014 - val_loss: 0.0016 - val_accuracy: 0.0029
# Epoch 55/100
# 12/12 [==============================] - 0s 20ms/step - loss: 1.9930e-04 - accuracy: 0.0014 - val_loss: 0.0014 - val_accuracy: 0.0029
# Epoch 56/100
# 12/12 [==============================] - 0s 27ms/step - loss: 1.9965e-04 - accuracy: 0.0014 - val_loss: 0.0014 - val_accuracy: 0.0029
# Epoch 57/100
# 12/12 [==============================] - 0s 24ms/step - loss: 1.8072e-04 - accuracy: 0.0014 - val_loss: 0.0015 - val_accuracy: 0.0029
# Epoch 58/100
# 12/12 [==============================] - 0s 19ms/step - loss: 1.7502e-04 - accuracy: 0.0014 - val_loss: 0.0014 - val_accuracy: 0.0029
# Epoch 59/100
# 12/12 [==============================] - 0s 19ms/step - loss: 1.7504e-04 - accuracy: 0.0014 - val_loss: 0.0019 - val_accuracy: 0.0029
# Epoch 60/100
# 12/12 [==============================] - 0s 19ms/step - loss: 1.7799e-04 - accuracy: 0.0014 - val_loss: 0.0017 - val_accuracy: 0.0029
# Epoch 61/100
# 12/12 [==============================] - 0s 19ms/step - loss: 1.7217e-04 - accuracy: 0.0014 - val_loss: 0.0015 - val_accuracy: 0.0029
# Epoch 62/100
# 12/12 [==============================] - 0s 19ms/step - loss: 1.7335e-04 - accuracy: 0.0014 - val_loss: 0.0017 - val_accuracy: 0.0029
# Epoch 63/100
# 12/12 [==============================] - 0s 18ms/step - loss: 1.8183e-04 - accuracy: 0.0014 - val_loss: 0.0015 - val_accuracy: 0.0029
# Epoch 64/100
# 12/12 [==============================] - 0s 19ms/step - loss: 1.7824e-04 - accuracy: 0.0014 - val_loss: 0.0016 - val_accuracy: 0.0029
# Epoch 65/100
# 12/12 [==============================] - 0s 19ms/step - loss: 1.7884e-04 - accuracy: 0.0014 - val_loss: 0.0017 - val_accuracy: 0.0029
# Epoch 66/100
# 12/12 [==============================] - 0s 19ms/step - loss: 1.7029e-04 - accuracy: 0.0014 - val_loss: 0.0020 - val_accuracy: 0.0029
# Epoch 67/100
# 12/12 [==============================] - 0s 20ms/step - loss: 1.6504e-04 - accuracy: 0.0014 - val_loss: 0.0026 - val_accuracy: 0.0029
# Epoch 68/100
# 12/12 [==============================] - 0s 19ms/step - loss: 1.6994e-04 - accuracy: 0.0014 - val_loss: 0.0015 - val_accuracy: 0.0029
# Epoch 69/100
# 12/12 [==============================] - 0s 19ms/step - loss: 1.5899e-04 - accuracy: 0.0014 - val_loss: 0.0018 - val_accuracy: 0.0029
# Epoch 70/100
# 12/12 [==============================] - 0s 18ms/step - loss: 1.7006e-04 - accuracy: 0.0014 - val_loss: 0.0019 - val_accuracy: 0.0029
# Epoch 71/100
# 12/12 [==============================] - 0s 18ms/step - loss: 1.6700e-04 - accuracy: 0.0014 - val_loss: 0.0017 - val_accuracy: 0.0029
# Epoch 72/100
# 12/12 [==============================] - 0s 19ms/step - loss: 1.8314e-04 - accuracy: 0.0014 - val_loss: 0.0018 - val_accuracy: 0.0029
# Epoch 73/100
# 12/12 [==============================] - 0s 19ms/step - loss: 1.6053e-04 - accuracy: 0.0014 - val_loss: 0.0015 - val_accuracy: 0.0029
# Epoch 74/100
# 12/12 [==============================] - 0s 19ms/step - loss: 1.5875e-04 - accuracy: 0.0014 - val_loss: 0.0015 - val_accuracy: 0.0029
# Epoch 75/100
# 12/12 [==============================] - 0s 19ms/step - loss: 1.6775e-04 - accuracy: 0.0014 - val_loss: 0.0023 - val_accuracy: 0.0029
# Epoch 76/100
# 12/12 [==============================] - 0s 19ms/step - loss: 1.7831e-04 - accuracy: 0.0014 - val_loss: 0.0014 - val_accuracy: 0.0029
# Epoch 77/100
# 12/12 [==============================] - 0s 19ms/step - loss: 1.4735e-04 - accuracy: 0.0014 - val_loss: 0.0027 - val_accuracy: 0.0029
# Epoch 78/100
# 12/12 [==============================] - 0s 18ms/step - loss: 1.5267e-04 - accuracy: 0.0014 - val_loss: 0.0018 - val_accuracy: 0.0029
# Epoch 79/100
# 12/12 [==============================] - 0s 18ms/step - loss: 1.4286e-04 - accuracy: 0.0014 - val_loss: 0.0022 - val_accuracy: 0.0029
# Epoch 80/100
# 12/12 [==============================] - 0s 18ms/step - loss: 1.4792e-04 - accuracy: 0.0014 - val_loss: 0.0018 - val_accuracy: 0.0029
# Epoch 81/100
# 12/12 [==============================] - 0s 19ms/step - loss: 1.5308e-04 - accuracy: 0.0014 - val_loss: 0.0022 - val_accuracy: 0.0029
# Epoch 82/100
# 12/12 [==============================] - 0s 19ms/step - loss: 1.4763e-04 - accuracy: 0.0014 - val_loss: 0.0016 - val_accuracy: 0.0029
# Epoch 83/100
# 12/12 [==============================] - 0s 19ms/step - loss: 1.4760e-04 - accuracy: 0.0014 - val_loss: 0.0021 - val_accuracy: 0.0029
# Epoch 84/100
# 12/12 [==============================] - 0s 19ms/step - loss: 1.6002e-04 - accuracy: 0.0014 - val_loss: 0.0019 - val_accuracy: 0.0029
# Epoch 85/100
# 12/12 [==============================] - 0s 19ms/step - loss: 1.5841e-04 - accuracy: 0.0014 - val_loss: 0.0014 - val_accuracy: 0.0029
# Epoch 86/100
# 12/12 [==============================] - 0s 19ms/step - loss: 1.5220e-04 - accuracy: 0.0014 - val_loss: 0.0020 - val_accuracy: 0.0029
# Epoch 87/100
# 12/12 [==============================] - 0s 18ms/step - loss: 1.8634e-04 - accuracy: 0.0014 - val_loss: 0.0031 - val_accuracy: 0.0029
# Epoch 88/100
# 12/12 [==============================] - 0s 18ms/step - loss: 1.6684e-04 - accuracy: 0.0014 - val_loss: 0.0016 - val_accuracy: 0.0029
# Epoch 89/100
# 12/12 [==============================] - 0s 19ms/step - loss: 1.4794e-04 - accuracy: 0.0014 - val_loss: 0.0024 - val_accuracy: 0.0029
# Epoch 90/100
# 12/12 [==============================] - 0s 19ms/step - loss: 1.4395e-04 - accuracy: 0.0014 - val_loss: 0.0016 - val_accuracy: 0.0029
# Epoch 91/100
# 12/12 [==============================] - 0s 19ms/step - loss: 1.3411e-04 - accuracy: 0.0014 - val_loss: 0.0016 - val_accuracy: 0.0029
# Epoch 92/100
# 12/12 [==============================] - 0s 19ms/step - loss: 1.3607e-04 - accuracy: 0.0014 - val_loss: 0.0023 - val_accuracy: 0.0029
# Epoch 93/100
# 12/12 [==============================] - 0s 19ms/step - loss: 1.4080e-04 - accuracy: 0.0014 - val_loss: 0.0020 - val_accuracy: 0.0029
# Epoch 94/100
# 12/12 [==============================] - 0s 19ms/step - loss: 1.4144e-04 - accuracy: 0.0014 - val_loss: 0.0017 - val_accuracy: 0.0029
# Epoch 95/100
# 12/12 [==============================] - 0s 18ms/step - loss: 1.3277e-04 - accuracy: 0.0014 - val_loss: 0.0020 - val_accuracy: 0.0029
# Epoch 96/100
# 12/12 [==============================] - 0s 19ms/step - loss: 1.2719e-04 - accuracy: 0.0014 - val_loss: 0.0019 - val_accuracy: 0.0029
# Epoch 97/100
# 12/12 [==============================] - 0s 19ms/step - loss: 1.2887e-04 - accuracy: 0.0014 - val_loss: 0.0016 - val_accuracy: 0.0029
# Epoch 98/100
# 12/12 [==============================] - 0s 19ms/step - loss: 1.3648e-04 - accuracy: 0.0014 - val_loss: 0.0021 - val_accuracy: 0.0029
# Epoch 99/100
# 12/12 [==============================] - 0s 25ms/step - loss: 1.3493e-04 - accuracy: 0.0014 - val_loss: 0.0021 - val_accuracy: 0.0029
# Epoch 100/100
# 12/12 [==============================] - 0s 30ms/step - loss: 1.3400e-04 - accuracy: 0.0014 - val_loss: 0.0020 - val_accuracy: 0.0029

# %%
train_predict = model.predict(x_train)
test_predict = model.predict(x_test)

# %%
# reverting back to the main original form from the scaled one 

train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)

# %%
import math ; from sklearn.metrics import mean_squared_error

# %%
print(math.sqrt(mean_squared_error(y_train,train_predict))) ; print(math.sqrt(mean_squared_error(y_test,test_predict)))
# Out:
# 142.8563423000204
# 242.374656617037
